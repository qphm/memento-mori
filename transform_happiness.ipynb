# %%
import pandas as pd

# %%
csv_path = "Raw Data/happinessrank.csv"
happiness_df = pd.read_csv(csv_path)
happiness_df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
happiness_df = happiness_df.drop(columns =['Lower Confidence Interval', 'Upper Confidence Interval',
                                          'Economy (GDP per Capita)','Family','Health (Life Expectancy)',
                                          'Freedom','Trust (Government Corruption)','Generosity','Dystopia Residual'])

# %%
happiness_df = happiness_df.drop(columns = ['Region'])

# %%
happiness_df = happiness_df.set_index('Country')

# %%
happiness_df
# Out:
#                       Happiness Rank  Happiness Score
# Country
# Denmark                            1            7.526
# Switzerland                        2            7.509
# Iceland                            3            7.501
# Norway                             4            7.498
# Finland                            5            7.413
# Canada                             6            7.404
# Netherlands                        7            7.339
# New Zealand                        8            7.334
# Australia                          9            7.313
# Sweden                            10            7.291
# Israel                            11            7.267
# Austria                           12            7.119
# United States                     13            7.104
# Costa Rica                        14            7.087
# Puerto Rico                       15            7.039
# Germany                           16            6.994
# ...

# %%
happiness_df.to_csv("CleanHappiness.csv")
